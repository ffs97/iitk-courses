# %%
# %matplotlib inline

# %%
import os
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
mpl.rc_file_defaults()

# %%
data = pd.read_csv("data.csv")

# %%
if not os.path.exists("./plots"):
    os.makedirs("./plots")

# %%
data
# Out:
#           Country  1930 - Cigarettes Smoked Per Year  \
# 0       Australia                                480
# 1          Canada                                500
# 2         Denmark                                380
# 3         Finland                               1100
# 4   Great Britain                               1100
# 5         Holland                                490
# 6         Iceland                                230
# 7          Norway                                250
# 8          Sweden                                300
# 9     Switzerland                                510
# 10  United States                               1300
#
#     1950 - Deaths/million of Lung Cancer
# 0                                    180
# 1                                    150
# 2                                    170
# 3                                    350
# 4                                    460
# 5                                    240
# 6                                     60
# 7                                     90
# 8                                    110
# 9                                    250
# 10                                   200

# %%
country_data = data.groupby("Country").sum()
country_data.plot.bar(color=["#cc88ff", "#ffcc88"])
plt.savefig("plots/a.png")
plt.show()

# %%
data["1930 - Cigarettes Smoked Per Year"].corr(data["1950 - Deaths/million of Lung Cancer"])
# Out:
# 0.7373450729981198
